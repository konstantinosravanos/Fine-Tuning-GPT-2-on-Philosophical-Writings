# %% [markdown]
# # <span style="color:cyan">DEFINITION OF THE WORKING DIRECTORY

# %%
pwd #Definition of the working directory
# Out:
# 'c:\\Users\\Kosta\\Desktop\\Python_Projects\\JUPYTER_PROJECT\\NLP Model'

# %% [markdown]
# # <span style="color:cyan">IMPORT OF THE REQUIRED LIBRARIES

# %%
# File handling, paths, and JSON
import json  # Used for parsing JSON data.
import os    # Provides a way of using operating system dependent functionality like reading or writing to the file system.

# Text processing
import re  # Regular expressions for text processing.
import nltk  # Natural Language Toolkit for working with human language data.
from nltk.tokenize import word_tokenize  # Used for tokenizing text into words or sentences.
from nltk.stem import WordNetLemmatizer  # Used for reducing words to their base or root form.
from nltk.corpus import stopwords, wordnet  # Stopwords are commonly used words that are usually filtered out before processing. Wordnet is a lexical database for the English language.
from nltk import pos_tag  # Part-of-speech tagging for a given word.

# Statistical analysis
import statistics as stat  # Provides functions to perform mathematical statistics on numeric (Real-valued) data.

# Orthographic checking
from autocorrect import Speller  # Used for automatic spell correction.

# Random selections (sampling)
import random as rd  # Supports the generation of random numbers, sequences, and sampling.

# Data analysis and CSV files
import pandas as pd  # Provides high-performance, easy-to-use data structures, and data analysis tools.
import csv  # Used for reading and writing CSV files.
import warnings  # Used to control the warnings generated by different modules.

# Machine Learning and Text Generation
from sklearn.model_selection import train_test_split # Used to split arrays or matrices into random train and test subsets.
from transformers import GPT2Tokenizer, GPT2LMHeadModel # GPT-2 tokenizer and model for text generation and understanding.
import tensorflow as tf # An end-to-end open-source platform for machine learning.
import gradio as gr # Gradio is a Python library that allows you to quickly create customizable UI components for machine learning models.
from transformers import pipeline  # Pipelines are a simple way to use models for common tasks.
from transformers import Trainer # Trainer is a high-level class that encapsulates the training loop.
from transformers import GPT2LMHeadModel, GPT2Tokenizer # GPT-2 tokenizer and model for text generation and understanding.
from transformers import TFGPT2LMHeadModel
from transformers import TextDataset, DataCollatorForLanguageModeling # TextDataset and DataCollatorForLanguageModeling are used for preparing the dataset and batching the data for training.
from transformers import TFAutoModelForCausalLM, AutoTokenizer
from transformers import TrainingArguments # TrainingArguments contains all the hyperparameters needed for training the model.
# Out:
# WARNING:tensorflow:From c:\Users\Kosta\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # <span style="color:cyan">REMOVAL OF PYTHON WARNINGS

# %%
# Deactivation of All Warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <span style="color:cyan">DATA PROCESSING

# %% [markdown]
# <span style="color:orange">Step 1: DEFINITION OF DIRECTORIES AND ENSURING THE FILES

# %%
inputFolder = "../Dataset/IData/"  # Define the input directory where the files are located.
all_quotes = []  # Create a list to store all the quotes.

for index, fileName in enumerate(os.listdir(inputFolder)):  # Iterate over each file in the input directory.
    if fileName.endswith(".txt"):  # Check if the file is a .txt file.
        philosopher = os.path.splitext(fileName)[0].lower()  # Extract the philosopher's name from the file name and convert it to lowercase.
        joinedPath = os.path.join(inputFolder, fileName)  # Create the full path to the file.

        with open(joinedPath, "r", encoding="utf-8", errors="replace") as initialFile:  # Open the file with UTF-8 encoding and replace any errors.
            quoteString = initialFile.readlines()  # Read all lines from the file.

        # Print the first 5 lines of the file for inspection.
        print(f"File: {fileName}")
        print("First 5 lines:")
        for line in quoteString[:5]:
            print(line.strip())  # Print each line after stripping leading/trailing whitespace.
        print("-" * 50)  # Print a line of dashes for better readability.

        # Add the philosopher's name and the quotes to the overall list of quotes.
        all_quotes.append((philosopher, quoteString))
# Out:
# File: Aristotle.txt
# First 5 lines:
# "Be a free thinker and don't accept everything you hear as truth. Be critical and evaluate what you believe in."
# "Excellence is never an accident. It is always the result of high intention, sincere effort, and intelligent execution; it represents the wise choice of many alternatives - choice, not chance, determines your destiny."
# "To appreciate the beauty of a snowflake, it is necessary to stand out in the cold."
# "He who cannot be a good follower cannot be a good leader."
# "The weak are always anxious for justice and equality. The strong pay no heed to either."
# --------------------------------------------------
# File: Artemiou.txt
# First 5 lines:
# "Many, are so concerned for the future, that they forget the present - from which everything is defined."
# "Finding a reason to die, is easier than finding a reason to live."
# "The only reason we are alive, is the reason itself."
# "When one is young, lives in bravery* but when old, lives in fear."
# "Fame, is a reward to be given not a target to be claimed."
# --------------------------------------------------
# File: Freud.txt
# First 5 lines:
# "In the small matters trust the mind, in the large ones the heart."
# "Unexpressed emotions will never die. They are buried alive and will come forth later in uglier ways."
# "One day, in retrospect, the years of struggle will strike you as the most beautiful."
# "We choose not randomly each other. We meet only those who already exists in our subconscious."
# "Most people do not really want freedom, because freedom involves responsibility, and most people are frightened of responsibility."
# --------------------------------------------------
# File: Kant.txt
# First 5 lines:
# "If you punish a child for being naughty, and reward him for being good, he will do right merely for the sake of the reward; and when he goes out into the world and finds that goodness is not always rewarded, nor wickedness always punished, he will grow into a man who only thinks about how he may get on in the world, and does right or wrong according as he finds advantage to himself."
# "You only know me as you see me, not as I actually am."
# "Rules for Happiness: something to do, someone to love, something to hope for."
# "We are not rich by what we possess but by what we can do without."
# "Three things tell a man: his eyes, his friends and his favorite quotes."
# --------------------------------------------------
# File: Sartre.txt
# First 5 lines:
# "We are our choices."
# "What is life but an unpleasant interruption to a peaceful nonexistence."
# "Every word has consequences. Every silence, too."
# "The worst part about being lied to is knowing you weren't worth the truth."
# "Only the guy who isn't rowing has time to rock the boat."
# --------------------------------------------------
# File: Schopenhauer.txt
# First 5 lines:
# "It is difficult to find happiness within oneself, but it is impossible to find it anywhere else."
# "All truth passes through three stages. First, it is ridiculed. Second, it is violently opposed. Third, it is accepted as being self-evident."
# "The wise have always said the same things, and fools, who are the majority have always done just the opposite."
# "The majority of men... are not capable of thinking, but only of believing, and... are not accessible to reason, but only to authority."
# "A pessimist is an optimist in full possession of the facts."
# --------------------------------------------------

# %% [markdown]
# <span style="color:orange">Step 2: CREATION OF A DICTIONARY WITH QUOTES AND THEIR AUTHORS

# %%
data = {}
for philosopher, quoteString in all_quotes:  # Traverse the list of quotes
    for k, text in enumerate(quoteString):
        quote = text.strip('\n').replace('"', "")  # Remove newline characters and quotes from the text
        data[len(data) + 1] = {"author": philosopher, "quote": quote}  # Add the author and quote to the dictionary with a unique ID

# Print results with the author at the beginning
for key, value in data.items():
    print(f"ID: {key}, Author: {value['author']}, Quote: {value['quote']}")
# Out:
# ID: 1, Author: aristotle, Quote: Be a free thinker and don't accept everything you hear as truth. Be critical and evaluate what you believe in.
# ID: 2, Author: aristotle, Quote: Excellence is never an accident. It is always the result of high intention, sincere effort, and intelligent execution; it represents the wise choice of many alternatives - choice, not chance, determines your destiny.
# ID: 3, Author: aristotle, Quote: To appreciate the beauty of a snowflake, it is necessary to stand out in the cold.
# ID: 4, Author: aristotle, Quote: He who cannot be a good follower cannot be a good leader.
# ID: 5, Author: aristotle, Quote: The weak are always anxious for justice and equality. The strong pay no heed to either.
# ID: 6, Author: aristotle, Quote: Courage is the first virtue that makes all other virtues possible.
# ID: 7, Author: aristotle, Quote: Laughter is a bodily exercise, precious to Health.
# ID: 8, Author: aristotle, Quote: Greatness of spirit is accompanied by simplicity and sincerity.
# ID: 9, Author: aristotle, Quote: Life is only meaningful when we are striving for a goal.
# ID: 10, Author: aristotle, Quote: The most important relationship we can all have is the one you have with yourself, the most important journey you can take is one of self-discovery. To know yourself, you must spend time with yourself, you must not be afraid to be alone. Knowing yourself is the beginning of all wisdom.
# ID: 11, Author: aristotle, Quote: Educating the mind without educating the heart is no education at all.
# ID: 12, Author: aristotle, Quote: The more you know, the more you know you don't know.
# ID: 13, Author: aristotle, Quote: 95% of everything you do is the result of habit.
# ID: 14, Author: aristotle, Quote: A tragedy is that moment where the hero comes face to face with his true identity.
# ID: 15, Author: aristotle, Quote: Men create gods after their own image, not only with regard to their form but with regard to their mode of life.
# ID: 16, Author: aristotle, Quote: It is our choice of good or evil that determines our character, not our opinion about good or evil.
# ID: 17, Author: aristotle, Quote: Our problem is not that we aim too high and miss, but that we aim too low and hit.
# ID: 18, Author: aristotle, Quote: Criticism is something we can avoid easily by saying nothing, doing nothing, and being nothing.
# ID: 19, Author: aristotle, Quote: At the intersection where your gifts, talents, and abilities meet a human need, therein you will discover your purpose.
# ID: 20, Author: aristotle, Quote: A fool contributes nothing worth hearing and takes offense at everything.
# ID: 21, Author: aristotle, Quote: Happiness is a quality of the soul...not a function of one's material circumstances.
# ID: 22, Author: aristotle, Quote: The worst form of inequality is to try to make unequal things equal.
# ID: 23, Author: aristotle, Quote: The high-minded man must care more for the truth than for what people think.
# ID: 24, Author: aristotle, Quote: Whosoever is delighted in solitude is either a wild beast or a god.
# ID: 25, Author: aristotle, Quote: True happiness comes from gaining insight and growing into your best possible self. Otherwise, all you're having is immediate gratification pleasure, which is fleeting and doesn't grow you as a person.
# ID: 26, Author: aristotle, Quote: The intelligence consists not only in the knowledge but also in the skill to apply the knowledge into practice.
# ID: 27, Author: aristotle, Quote: Doubt is the beginning of wisdom.
# ID: 28, Author: aristotle, Quote: The most perfect political community is one in which the middle class is in control, and outnumbers both of the other classes.
# ID: 29, Author: aristotle, Quote: Humility is a flower that does not grow in everyone's garden.
# ID: 30, Author: aristotle, Quote: The best things are placed between extremes.
# ID: 31, Author: aristotle, Quote: Character is determined by choice, not opinion.
# ID: 32, Author: aristotle, Quote: Pleasure in the job puts perfection in the work.
# ID: 33, Author: aristotle, Quote: The worst thing about slavery is that the slaves eventually get to like it.
# ID: 63, Author: aristotle, Quote: He who has never learned to obey cannot be a good commander.
# ID: 64, Author: aristotle, Quote: Today, see if you can stretch your heart and expand your love so that it touches not only those to whom you can give it easily, but also to those who need it so much.
# ID: 65, Author: aristotle, Quote: No great mind has ever existed without a touch of madness.
# ID: 66, Author: aristotle, Quote: Knowing yourself is the beginning of all wisdom.
# ID: 67, Author: aristotle, Quote: Whatever we learn to do, we learn by actually doing it; men come to be builders, for instance, by building, and harp players by playing the harp. In the same way, by doing just acts we come to be just; by doing self-controlled acts, we come to be self-controlled; and by doing brave acts, we become brave.
# ID: 68, Author: aristotle, Quote: The greatest thing by far is to be a master of metaphor; it is the one thing that cannot be learned from others; and it is also a sign of genius, since a good metaphor implies an intuitive perception of the similarity of the dissimilar.
# ID: 69, Author: aristotle, Quote: The society that loses its grip on the past is in danger, for it produces men who know nothing but the present, and who are not aware that life had been, and could be, different from what it is.
# ID: 70, Author: aristotle, Quote: Courage is the mother of all virtues because without it, you cannot consistently perform the others.
# ID: 71, Author: aristotle, Quote: Teenagers these days are out of control. They eat like pigs, they are disrespectful of adults, they interrupt and contradict their parents, and they terrorize their teachers.
# ID: 72, Author: aristotle, Quote: Character is made by many acts; it may be lost by a single one.
# ID: 73, Author: aristotle, Quote: The man who is perfect and wise will bear with dignity whatever fortune sends, and will always make the best of his circumstances.
# ID: 74, Author: aristotle, Quote: Find the good. Seek unity. Ignore the divisions among us.
# ID: 75, Author: aristotle, Quote: The greatest of all pleasures is the pleasure of learning.
# ID: 76, Author: aristotle, Quote: The tyrant, who in order to hold his power, suppresses every superiority, does away with good men, forbids education and light, controls every movement of the citizens and, keeping them under a perpetual servitude, wants them to grow accustomed to baseness and cowardice, has his spies everywhere to listen to what is said in the meetings, and spreads dissension and calumny among the citizens and impoverishes them, is obliged to make war in order to keep his subjects occupied and impose on them permanent need of a chief.
# ID: 77, Author: aristotle, Quote: Poverty is the parent of revolution and crime.
# ID: 78, Author: aristotle, Quote: The hardest victory is the victory over self.
# ID: 79, Author: aristotle, Quote: Republics decline into democracies and democracies degenerate into despotism.
# ID: 80, Author: aristotle, Quote: Fortune favors the bold.
# ID: 81, Author: aristotle, Quote: You are what you repeatedly do.
# ID: 82, Author: aristotle, Quote: Your happiness depends on you alone.
# ID: 83, Author: aristotle, Quote: Patience is bitter, but it is fruit is sweet.
# ID: 84, Author: aristotle, Quote: Wise people have an inward sense of what is beautiful, and the highest wisdom is to trust this intuition and be guided by it.
# ID: 85, Author: aristotle, Quote: Knowledge of the fact differs from knowledge of the reason for the fact.
# ID: 86, Author: aristotle, Quote: The energy of the mind is the essence of life.
# ID: 87, Author: aristotle, Quote: The aim of the wise is not to secure pleasure, but to avoid pain.
# ID: 88, Author: aristotle, Quote: Our feelings towards our friends reflect our feelings towards ourselves.
# ID: 89, Author: aristotle, Quote: They - young people have exalted notions, because they have not been humbled by life or learned its necessary limitations; moreover, their hopeful disposition makes them think themselves equal to great things - and that means having exalted notions. They would always rather do noble deeds than useful ones: Their lives are regulated more by moral feeling than by reasoning - all their mistakes are in the direction of doing things excessively and vehemently. They overdo everything - they love too much, hate too much, and the same with everything else.
# ID: 90, Author: aristotle, Quote: Through discipline comes freedom.
# ID: 91, Author: aristotle, Quote: The quality of life is determined by its activities.
# ID: 92, Author: aristotle, Quote: What you have to learn to do, you learn by doing.
# ID: 93, Author: aristotle, Quote: Man is a goal-seeking animal. His life only has meaning if he is reaching out and striving for his goals.
# ID: 94, Author: aristotle, Quote: All persons ought to endeavor to follow what is right, and not what is established.
# ID: 95, Author: aristotle, Quote: A goal gets us motivated, while a good habit keeps us stay motivated.
# ID: 96, Author: aristotle, Quote: The best way to avoid envy is to deserve the success you get.
# ID: 97, Author: aristotle, Quote: You can never learn anything that you did not already know.
# ID: 98, Author: aristotle, Quote: There is nothing unequal as the equal treatment of unequals.
# ID: 99, Author: aristotle, Quote: Virtue means doing the right thing, in relation to the right person, at the right time, to the right extent, in the right manner, and for the right purpose. Thus, to give money away is quite a simple task, but for the act to be virtuous, the donor must give to the right person, for the right purpose, in the right amount, in the right manner, and at the right time.
# ID: 100, Author: aristotle, Quote: It is a part of probability that many improbable things will happen.
# ID: 101, Author: aristotle, Quote: Those that know, do. Those that understand, teach.
# ID: 102, Author: aristotle, Quote: We are the sum of our actions, and therefore our habits make all the difference.
# ID: 103, Author: aristotle, Quote: It is impossible, or not easy, to alter by argument what has long been absorbed by habit.
# ID: 104, Author: aristotle, Quote: Let us first understand the facts, and then we may seek the cause.
# ID: 105, Author: aristotle, Quote: We laugh at that which we cannot bear to face.
# ID: 106, Author: aristotle, Quote: Peace is more difficult than war.
# ID: 107, Author: aristotle, Quote: You are what you do repeatedly.
# ID: 108, Author: aristotle, Quote: Anyone who has no need of anybody but himself is either a beast or a God.
# ID: 109, Author: aristotle, Quote: The greatest crimes are caused by surfeit, not by want.
# ID: 110, Author: aristotle, Quote: To Unlearn is as hard as to Learn.
# ID: 111, Author: aristotle, Quote: Every man should be responsible to others, nor should anyone be allowed to do just as he pleases; for where absolute freedom is allowed, there is nothing to restrain the evil which is inherent in every man.
# ID: 112, Author: aristotle, Quote: The only way to achieve true success is to express yourself completely in service to society.
# ID: 113, Author: aristotle, Quote: Friends hold a mirror up to each other; through that mirror they can see each other in ways that would not otherwise be accessible to them, and it is this mirroring that helps them improve themselves as persons.
# ID: 114, Author: aristotle, Quote: A proper wife should be as obedient as a slave... The female is a female by virtue of a certain lack of qualities - a natural defectiveness.
# ID: 115, Author: aristotle, Quote: Love is composed of a single soul inhabiting two bodies.
# ID: 116, Author: aristotle, Quote: Love well, be loved and do something of value.
# ID: 117, Author: aristotle, Quote: Happiness is a state of activity.
# ID: 118, Author: aristotle, Quote: Man is by nature a social animal; an individual who is unsocial naturally and not accidentally is either beneath our notice or more than human. Society is something that precedes the individual. Anyone who either cannot lead the common life or is so self-sufficient as not to need to, and therefore does not partake of society, is either a beast or a god.
# ID: 119, Author: aristotle, Quote: Fine friendship requires duration rather than fitful intensity.
# ID: 120, Author: aristotle, Quote: The physician himself, if sick, actually calls in another physician, knowing that he cannot reason correctly if required to judge his own condition while suffering.
# ID: 187, Author: aristotle, Quote: If men are given food, but no chastisement nor any work, they become insolent.
# ID: 188, Author: aristotle, Quote: Friends are much better tried in bad fortune than in good.
# ID: 189, Author: aristotle, Quote: Happiness is the reward of virtue.
# ID: 190, Author: aristotle, Quote: It is the characteristic of the magnanimous man to ask no favor but to be ready to do kindness to others.
# ID: 191, Author: aristotle, Quote: The senses are gateways to the intelligence. There is nothing in the intelligence that did not first pass through the senses.
# ID: 192, Author: aristotle, Quote: We become just by the practice of just actions, self-controlled by exercising self-control, and courageous by performing acts of courage.
# ID: 193, Author: aristotle, Quote: It is more difficult to organize a peace than to win a war; but the fruits of victory will be lost if the peace is not organized.
# ID: 194, Author: aristotle, Quote: What it lies in our power to do, it lies in our power not to do.
# ID: 195, Author: aristotle, Quote: If you understand anything, observe its beginning and its development.
# ID: 196, Author: aristotle, Quote: If things do not turn out as we wish, we should wish for them as they turn out.
# ID: 197, Author: aristotle, Quote: Man is by nature a political animal.
# ID: 198, Author: aristotle, Quote: The ultimate end...is not knowledge, but action. To be half right on time may be more important than to obtain the whole truth too late.
# ID: 199, Author: aristotle, Quote: The only stable state is the one in which all men are equal before the law.
# ID: 200, Author: aristotle, Quote: Saying the words that come from knowledge is no sign of having it.
# ID: 201, Author: aristotle, Quote: A friend is another I.
# ID: 202, Author: aristotle, Quote: The whole is more than the sum of its parts.
# ID: 203, Author: aristotle, Quote: Worthless persons appointed to have supreme control of weighty affairs do a lot of damage.
# ID: 204, Author: aristotle, Quote: The habits we form from childhood make no small difference, but rather they make all the difference.
# ID: 205, Author: aristotle, Quote: Our characters are the result of our conduct.
# ID: 206, Author: aristotle, Quote: The soul never thinks without a picture.
# ID: 207, Author: aristotle, Quote: Perception starts with the eye.
# ID: 208, Author: aristotle, Quote: There's many a slip between the cup and the lip.
# ID: 209, Author: aristotle, Quote: The greatest thing by far is to have a command of metaphor. This alone cannot be imparted by another; it is the mark of genius, for to make good metaphors implies an eye for resemblances.
# ID: 210, Author: aristotle, Quote: Men are marked from the moment of birth to rule or be ruled.
# ID: 211, Author: aristotle, Quote: My best friend is the man who in wishing me well wishes it for my sake.
# ID: 212, Author: aristotle, Quote: To say of what is that it is not, or of what is not that it is, is false, while to say of what is that it is, and of what is not that it is not, is true.
# ID: 213, Author: aristotle, Quote: We should behave to our friends as we would wish our friends to behave to us.
# ID: 214, Author: aristotle, Quote: Happiness does not consist in pastimes and amusements but in virtuous activities.
# ID: 215, Author: aristotle, Quote: Truth is a remarkable thing. We cannot miss knowing some of it. But we cannot know it entirely.
# ID: 216, Author: aristotle, Quote: Jealousy is both reasonable and belongs to reasonable men, while envy is base and belongs to the base, for the one makes himself get good things by jealousy, while the other does not allow his neighbor to have them through envy.
# ID: 217, Author: aristotle, Quote: Fear is pain arising from the anticipation of evil.
# ID: 218, Author: aristotle, Quote: We are what we do.
# ID: 219, Author: aristotle, Quote: Excellence, therefore, is not an act, but a habit.
# ID: 220, Author: aristotle, Quote: He who hath many friends hath none.
# ID: 221, Author: aristotle, Quote: No state will be well administered unless the middle class holds sway.
# ID: 279, Author: aristotle, Quote: Liars when they speak the truth are not believed.
# ID: 280, Author: aristotle, Quote: Happiness involves engagement in activities that promote one's highest potential.
# ID: 281, Author: aristotle, Quote: The Life of the intellect is the best and pleasantest for man, because the intellect more than anything else is the man. Thus, it will be the happiest life as well.
# ID: 282, Author: aristotle, Quote: Music directly imitates the passions or states of the soul...when one listens to music that imitates a certain passion, he becomes imbued with the same passion; and if over a long time he habitually listens to music that rouses ignoble passions, his whole character will be shaped to an ignoble form.
# ID: 283, Author: aristotle, Quote: We give up leisure in order that we may have leisure, just as we go to war in order that we may have peace.
# ID: 284, Author: aristotle, Quote: Meanness is incurable; it cannot be cured by old age or by anything else.
# ID: 285, Author: aristotle, Quote: There is no genius who hasn't a touch of insanity.
# ID: 286, Author: aristotle, Quote: We must be neither cowardly nor rash but courageous.
# ID: 287, Author: aristotle, Quote: Memory is the scribe of the soul.
# ID: 288, Author: aristotle, Quote: Each human being is bred with a unique set of potentials that yearn to be fulfilled as surely as the acorn yearns to become the oak within it.
# ID: 289, Author: aristotle, Quote: The true nature of anything is what it becomes at its highest.
# ID: 290, Author: aristotle, Quote: Why do men seek honour? Surely, in order to confirm the favorable opinion, they have formed of themselves.
# ID: 291, Author: aristotle, Quote: Salt water when it turns into vapour becomes sweet, and the vapour does not form salt water when it condenses again. This I know by experiment. The same thing is true in every case of the kind: wine and all fluids that evaporate and condense back into a liquid state become water. They all are water modified by a certain admixture, the nature of which determines their flavor.
# ID: 292, Author: aristotle, Quote: To give away money is an easy matter and in any man's power. But to decide to whom to give it and how large and when, and for what purpose and how, is neither in every man's power nor an easy matter.
# ID: 293, Author: aristotle, Quote: Democracy is the form of government in which the free, are rulers.
# ID: 294, Author: aristotle, Quote: Mothers are fonder than fathers of their children because they are more certain they are their own.
# ID: 295, Author: aristotle, Quote: Neither should we forget the mean, which at the present day is lost sight of in perverted forms of government; for many practices which appear to be democratic are the ruin of democracies. Those who think that all virtue is to be found in their own party principles push matters to extremes; they do not consider that disproportion destroys a state.
# ID: 296, Author: aristotle, Quote: A flatterer is a friend who is your inferior, or pretends to be so.
# ID: 297, Author: aristotle, Quote: That which is excellent endures.
# ID: 298, Author: aristotle, Quote: The aim of art is to represent not the outward appearance of things, but their inward significance.
# ID: 299, Author: aristotle, Quote: A man's happiness consists in the free exercise of his highest faculties.
# ID: 300, Author: aristotle, Quote: For, what is the best choice for each individual is the highest it is possible for him to achieve.
# ID: 301, Author: aristotle, Quote: Good has two meanings: it means that which is good absolutely and that which is good for somebody.
# ID: 302, Author: aristotle, Quote: Excellence is an art won by training and habituation. We do not act rightly because we have virtue or excellence, but we rather have those because we have acted rightly. We are what we repeatedly do. Excellence, then, is not an act but a habit.
# ID: 303, Author: aristotle, Quote: Law is a mind without reason.
# ID: 304, Author: aristotle, Quote: Those who act receive the prizes.
# ID: 305, Author: aristotle, Quote: Suppose, then, that all men were sick or deranged, save one or two of them who were healthy and of right mind. It would then be the latter two who would be thought to be sick and deranged, and the former not.
# ID: 306, Author: aristotle, Quote: That which is impossible and probable is better than that which is possible and improbable.
# ID: 2529, Author: schopenhauer, Quote: Something of great importance now past is inferior to something of little importance now present, in that the latter is a reality, and related to the former as something to nothing.
# ID: 2530, Author: schopenhauer, Quote: Whether we are in a pleasant or a painful state depends, finally, upon the kind of matter that pervades and engrosses our consciousness and what we compare it to - better and we envious and sad, worse and we feel grateful and happy.
# ID: 2531, Author: schopenhauer, Quote: Talent works for money and fame; the motive which moves genius to productivity is, on the other hand, less easy to determine.
# ID: 2532, Author: schopenhauer, Quote: To expect a man to retain everything that he has ever read is like expecting him to carry about in his body everything that he has ever eaten.
# ID: 2533, Author: schopenhauer, Quote: If there is anything in the world that can really be called a man's property, it is surely that which is the result of his mental activity.
# ID: 2534, Author: schopenhauer, Quote: It is only when a man is alone that he is really free.
# ID: 2535, Author: schopenhauer, Quote: The principle of contradiction establishes merely the agreement of concepts, but does not itself produce concepts.
# ID: 2536, Author: schopenhauer, Quote: Honor means that a man is not exceptional; fame, that he is.
# ID: 2537, Author: schopenhauer, Quote: Faith is like love, it cannot be forced. Therefore it is a dangerous operation if an attempt be made to introduce or bind it by state regulations; for, as the attempt to force love begets hatred, so also to compel religious belief produces rank unbelief.
# ID: 2538, Author: schopenhauer, Quote: Whatever folly men commit, be their shortcomings or their vices what they may, let us exercise forbearance; remember that when these faults appear in others it is our follies and vices that we behold.
# ID: 2539, Author: schopenhauer, Quote: As the biggest library if it is in disorder is not as useful as a small but well-arranged one, so you may accumulate a vast amount of knowledge but it will be of far less value to you than a much smaller amount if you have not thought it over for yourself; because only through ordering what you know by comparing every truth with every other truth can you take complete possession of your knowledge and get it into your power. You can think about only what you know, so you ought to learn something; on the other hand, you can know only what you have thought about.
# ID: 2540, Author: schopenhauer, Quote: Memory works like the collection glass in the Camera obscura: it gathers everything together and therewith produces a far more beautiful picture than was present originally.
# ID: 2541, Author: schopenhauer, Quote: Honour is external conscience, and conscience is inward honour.
# ID: 2542, Author: schopenhauer, Quote: There is a wide difference between the original thinker and the merely learned man.
# ID: 2543, Author: schopenhauer, Quote: It is difficult, if not impossible, to define the limit of our reasonable desires in respect of possessions.
# ID: 2544, Author: schopenhauer, Quote: Every state of welfare, every feeling of satisfaction, is negative in its character; that is to say, it consists in freedom from pain, which is the positive element of existence.
# ID: 2545, Author: schopenhauer, Quote: The greatest intellectual capacities are only found in connection with a vehement and passionate will.
# ID: 2546, Author: schopenhauer, Quote: The happiness which we receive from ourselves is greater than that which we obtain from our surroundings... The world in which a person lives shapes itself chiefly by the way in which he or she looks at it.
# ID: 2547, Author: schopenhauer, Quote: It is a clumsy experiment to make; for it involves the destruction of the very consciousness which puts the question and awaits the answer.
# ID: 2548, Author: schopenhauer, Quote: What a man is: that is to say, personality, in the widest sense of the word; under which are included health, strength, beauty, temperament, moral character, intelligence, and education.
# ID: 2549, Author: schopenhauer, Quote: Knowledge is to certain extent a second existence.
# ID: 2550, Author: schopenhauer, Quote: The composer reveals the innermost nature of the world, and expresses the profoundest wisdom in a language that his reasoning faculty does not understand, just as a magnetic somnambulist gives information about things of which she has no conception when she is awake. Therefore in the composer, more than in any other artist, the man is entirely separate and distinct from the artist.

# %% [markdown]
# <span style="color:orange">Step 3: STATISTICAL FILTERING OF OUTLIERS

# %%
# Calculation of the mean and standard deviation of the quotes' lengths
lengthList = [len(quote["quote"]) for quote in data.values()]  # Create a list of lengths of all quotes in the dictionary
meanLength = stat.mean(lengthList)  # Calculate the mean length of the quotes
standardLength = stat.stdev(lengthList)  # Calculate the standard deviation of the quotes' lengths

# Definition of the allowed range
tolerance = 1.11  # Define a tolerance level to determine the range of acceptable quote lengths
minLength = meanLength - tolerance * standardLength  # Calculate the minimum length of quotes to be considered
maxLength = meanLength + tolerance * standardLength  # Calculate the maximum length of quotes to be considered

# Filtering of quotes that fall within the allowed range
filteredQuotes = [quote for quote in data.values() if minLength <= len(quote["quote"]) <= maxLength]  # Filter quotes based on their length
# Print results
print(f"Mean Length: {meanLength}")  # Print the mean length of the quotes
print(f"Standard Deviation: {standardLength}")  # Print the standard deviation of the quotes' lengths
print(f"Number of original quotes: {len(data)}")  # Print the total number of original quotes
print(f"Number of allowed quotes: {len(filteredQuotes)}")  # Print the number of quotes that fall within the allowed length range
print(f"Number of filtered quotes: {len(filteredQuotes)}")  # Print the number of quotes that have been filtered

# Print the filtered quotes
print("\nFiltered Quotes:")
for i, quote in enumerate(filteredQuotes, 1):
    print(f"{i}. Author: {quote['author']}, Quote: {quote['quote']}")  # Print each filtered quote along with its author
# Out:
# Mean Length: 122.70196078431373
# Standard Deviation: 96.96864342177864
# Number of original quotes: 2550
# Number of allowed quotes: 2262
# Number of filtered quotes: 2262
#
# Filtered Quotes:
# 1. Author: aristotle, Quote: Be a free thinker and don't accept everything you hear as truth. Be critical and evaluate what you believe in.
# 2. Author: aristotle, Quote: Excellence is never an accident. It is always the result of high intention, sincere effort, and intelligent execution; it represents the wise choice of many alternatives - choice, not chance, determines your destiny.
# 3. Author: aristotle, Quote: To appreciate the beauty of a snowflake, it is necessary to stand out in the cold.
# 4. Author: aristotle, Quote: He who cannot be a good follower cannot be a good leader.
# 5. Author: aristotle, Quote: The weak are always anxious for justice and equality. The strong pay no heed to either.
# 6. Author: aristotle, Quote: Courage is the first virtue that makes all other virtues possible.
# 7. Author: aristotle, Quote: Laughter is a bodily exercise, precious to Health.
# 8. Author: aristotle, Quote: Greatness of spirit is accompanied by simplicity and sincerity.
# 9. Author: aristotle, Quote: Life is only meaningful when we are striving for a goal.
# 10. Author: aristotle, Quote: Educating the mind without educating the heart is no education at all.
# 11. Author: aristotle, Quote: The more you know, the more you know you don't know.
# 12. Author: aristotle, Quote: 95% of everything you do is the result of habit.
# 13. Author: aristotle, Quote: A tragedy is that moment where the hero comes face to face with his true identity.
# 14. Author: aristotle, Quote: Men create gods after their own image, not only with regard to their form but with regard to their mode of life.
# 15. Author: aristotle, Quote: It is our choice of good or evil that determines our character, not our opinion about good or evil.
# 16. Author: aristotle, Quote: Our problem is not that we aim too high and miss, but that we aim too low and hit.
# 17. Author: aristotle, Quote: Criticism is something we can avoid easily by saying nothing, doing nothing, and being nothing.
# 91. Author: aristotle, Quote: There is nothing unequal as the equal treatment of unequals.
# 92. Author: aristotle, Quote: It is a part of probability that many improbable things will happen.
# 93. Author: aristotle, Quote: Those that know, do. Those that understand, teach.
# 94. Author: aristotle, Quote: We are the sum of our actions, and therefore our habits make all the difference.
# 95. Author: aristotle, Quote: It is impossible, or not easy, to alter by argument what has long been absorbed by habit.
# 96. Author: aristotle, Quote: Let us first understand the facts, and then we may seek the cause.
# 97. Author: aristotle, Quote: We laugh at that which we cannot bear to face.
# 98. Author: aristotle, Quote: Peace is more difficult than war.
# 99. Author: aristotle, Quote: You are what you do repeatedly.
# 100. Author: aristotle, Quote: Anyone who has no need of anybody but himself is either a beast or a God.
# 101. Author: aristotle, Quote: The greatest crimes are caused by surfeit, not by want.
# 102. Author: aristotle, Quote: To Unlearn is as hard as to Learn.
# 103. Author: aristotle, Quote: Every man should be responsible to others, nor should anyone be allowed to do just as he pleases; for where absolute freedom is allowed, there is nothing to restrain the evil which is inherent in every man.
# 104. Author: aristotle, Quote: The only way to achieve true success is to express yourself completely in service to society.
# 105. Author: aristotle, Quote: Friends hold a mirror up to each other; through that mirror they can see each other in ways that would not otherwise be accessible to them, and it is this mirroring that helps them improve themselves as persons.
# 106. Author: aristotle, Quote: A proper wife should be as obedient as a slave... The female is a female by virtue of a certain lack of qualities - a natural defectiveness.
# 107. Author: aristotle, Quote: Love is composed of a single soul inhabiting two bodies.
# 108. Author: aristotle, Quote: Love well, be loved and do something of value.
# 109. Author: aristotle, Quote: Happiness is a state of activity.
# 110. Author: aristotle, Quote: Fine friendship requires duration rather than fitful intensity.
# 111. Author: aristotle, Quote: The physician himself, if sick, actually calls in another physician, knowing that he cannot reason correctly if required to judge his own condition while suffering.
# 112. Author: aristotle, Quote: Money is a guarantee that we can have what we want in the future.
# 113. Author: aristotle, Quote: Those who cannot bravely face danger are the slaves of their attackers.
# 114. Author: aristotle, Quote: The beauty of the soul shines out when a man bears with composure one heavy mischance after another, not because he feels them, but because he is a man of high and heroic temper.
# 115. Author: aristotle, Quote: Happiness belongs to the self-sufficient.
# 116. Author: aristotle, Quote: Health is a matter of choice, not a mystery of chance.
# 117. Author: aristotle, Quote: To love someone is to identify with them.
# 118. Author: aristotle, Quote: He overcomes a stout enemy who overcomes his own anger.
# 119. Author: aristotle, Quote: All men seek one goal: success or happiness.
# 120. Author: aristotle, Quote: Democracy is when the indigent, and not the men of property, are the rulers.
# 121. Author: aristotle, Quote: It is well to be up before daybreak, for such habits contribute to health, wealth, and wisdom.
# 122. Author: aristotle, Quote: Philosophy begins with wonder.
# 123. Author: aristotle, Quote: Speech is the representation of the mind, and writing is the representation of speech.
# 124. Author: aristotle, Quote: Plato is my friend, but truth is a better friend.
# 125. Author: aristotle, Quote: We should aim rather at leveling down our desires than leveling up our means.
# 126. Author: aristotle, Quote: At his best, man is the noblest of all animals; separated from law and justice, he is the worst.
# 127. Author: aristotle, Quote: It would be wrong to put friendship before the truth.
# 128. Author: aristotle, Quote: The difference between a learned man and an ignorant one is the same as that between a living man and a corpse.
# 166. Author: aristotle, Quote: Reason is a light that God has kindled in the soul.
# 167. Author: aristotle, Quote: What we expect, that we find.
# 168. Author: aristotle, Quote: We are better able to study our neighbours than ourselves and their actions than our own.
# 169. Author: aristotle, Quote: We work to earn our leisure.
# 170. Author: aristotle, Quote: Friendship is a single soul dwelling in two bodies.
# 171. Author: aristotle, Quote: Female cats are very Lascivious, and make advances to the male.
# 172. Author: aristotle, Quote: Wit is well-bred insolence.
# 173. Author: aristotle, Quote: Dignity does not consist in possessing honors, but in deserving them.
# 174. Author: aristotle, Quote: He who sees things grow from the beginning will have the best view of them.
# 175. Author: aristotle, Quote: Time crumbles things; everything grows old under the power of Time and is forgotten through the lapse of Time.
# 176. Author: aristotle, Quote: If men are given food, but no chastisement nor any work, they become insolent.
# 177. Author: aristotle, Quote: Friends are much better tried in bad fortune than in good.
# 178. Author: aristotle, Quote: Happiness is the reward of virtue.
# 179. Author: aristotle, Quote: It is the characteristic of the magnanimous man to ask no favor but to be ready to do kindness to others.
# 180. Author: aristotle, Quote: The senses are gateways to the intelligence. There is nothing in the intelligence that did not first pass through the senses.
# 181. Author: aristotle, Quote: We become just by the practice of just actions, self-controlled by exercising self-control, and courageous by performing acts of courage.
# 182. Author: aristotle, Quote: It is more difficult to organize a peace than to win a war; but the fruits of victory will be lost if the peace is not organized.
# 183. Author: aristotle, Quote: What it lies in our power to do, it lies in our power not to do.
# 184. Author: aristotle, Quote: If you understand anything, observe its beginning and its development.
# 185. Author: aristotle, Quote: If things do not turn out as we wish, we should wish for them as they turn out.
# 186. Author: aristotle, Quote: Man is by nature a political animal.
# 187. Author: aristotle, Quote: The ultimate end...is not knowledge, but action. To be half right on time may be more important than to obtain the whole truth too late.
# 188. Author: aristotle, Quote: The only stable state is the one in which all men are equal before the law.
# 189. Author: aristotle, Quote: Saying the words that come from knowledge is no sign of having it.
# 190. Author: aristotle, Quote: A friend is another I.
# 191. Author: aristotle, Quote: The whole is more than the sum of its parts.
# 192. Author: aristotle, Quote: Worthless persons appointed to have supreme control of weighty affairs do a lot of damage.
# 193. Author: aristotle, Quote: The habits we form from childhood make no small difference, but rather they make all the difference.
# 194. Author: aristotle, Quote: Our characters are the result of our conduct.
# 195. Author: aristotle, Quote: The soul never thinks without a picture.
# 196. Author: aristotle, Quote: Perception starts with the eye.
# 197. Author: aristotle, Quote: There's many a slip between the cup and the lip.
# 198. Author: aristotle, Quote: The greatest thing by far is to have a command of metaphor. This alone cannot be imparted by another; it is the mark of genius, for to make good metaphors implies an eye for resemblances.
# 199. Author: aristotle, Quote: Men are marked from the moment of birth to rule or be ruled.
# 200. Author: aristotle, Quote: My best friend is the man who in wishing me well wishes it for my sake.
# 201. Author: aristotle, Quote: To say of what is that it is not, or of what is not that it is, is false, while to say of what is that it is, and of what is not that it is not, is true.
# 202. Author: aristotle, Quote: We should behave to our friends as we would wish our friends to behave to us.
# 203. Author: aristotle, Quote: Happiness does not consist in pastimes and amusements but in virtuous activities.
# 204. Author: aristotle, Quote: Truth is a remarkable thing. We cannot miss knowing some of it. But we cannot know it entirely.
# 205. Author: aristotle, Quote: Jealousy is both reasonable and belongs to reasonable men, while envy is base and belongs to the base, for the one makes himself get good things by jealousy, while the other does not allow his neighbor to have them through envy.
# 206. Author: aristotle, Quote: Fear is pain arising from the anticipation of evil.
# 207. Author: aristotle, Quote: We are what we do.
# 208. Author: aristotle, Quote: Excellence, therefore, is not an act, but a habit.
# 209. Author: aristotle, Quote: He who hath many friends hath none.
# 210. Author: aristotle, Quote: No state will be well administered unless the middle class holds sway.
# 211. Author: aristotle, Quote: By myth, I mean the arrangement of the incidents.
# 212. Author: aristotle, Quote: The honors and rewards fall to those who show their good qualities in action.
# 213. Author: aristotle, Quote: Happiness is the meaning and the purpose of life, the whole aim and end of human existence.
# 214. Author: aristotle, Quote: Excellence, then, is a state concerned with choice, lying in a mean, relative to us, this being determined by reason and in the way in which the man of practical wisdom would determine it.
# 215. Author: aristotle, Quote: No one loves the man whom he fears.
# 216. Author: aristotle, Quote: For what one has to learn to do, we learn by doing.
# 217. Author: aristotle, Quote: Happiness is the settling of the soul into its most appropriate spot.
# 218. Author: aristotle, Quote: It is no easy task to be good.
# 219. Author: aristotle, Quote: The Nature of man is not what he was born as, but what he is born for.
# 220. Author: aristotle, Quote: Worms are the intestines of the earth.
# 221. Author: aristotle, Quote: True happiness flows from the possession of wisdom and virtue and not from the possession of external goods.
# 222. Author: aristotle, Quote: The hand is the tool of tools.
# 223. Author: aristotle, Quote: Friends enhance our ability to think and act.
# 224. Author: aristotle, Quote: We are what we frequently do.
# 225. Author: aristotle, Quote: Beauty is the gift of God.
# 226. Author: aristotle, Quote: Bad people...are in conflict with themselves; they desire one thing and will another, like the incontinent who choose harmful pleasures instead of what they themselves believe to be good.
# 227. Author: aristotle, Quote: Good moral character is not something that we can achieve on our own. We need a culture that supports the conditions under which self-love and friendship flourish.
# 228. Author: aristotle, Quote: To write well, express yourself like the common people, but think like a wise man.
# 229. Author: aristotle, Quote: Teachers, who educate children, deserve more honor than parents, who merely gave them birth; for the latter provided mere life, while the former ensure a good life.
# 230. Author: aristotle, Quote: The complete man must work, study and wrestle.
# 231. Author: aristotle, Quote: Well begun is half done.
# 232. Author: aristotle, Quote: Even that some people try deceived me many times ... I will not fail to believe that somewhere, someone deserves my trust.
# 233. Author: aristotle, Quote: A person's life persuades better than his word.
# 234. Author: aristotle, Quote: All Earthquakes and Disasters are warnings; there s too much corruption in the world.
# 235. Author: aristotle, Quote: A common danger unites even the bitterest enemies.
# 236. Author: aristotle, Quote: Being a father is the most rewarding thing a man whose career has plateaued can do.
# 237. Author: aristotle, Quote: It is simplicity that makes the uneducated more effective than the educated when addressing popular audiences.
# 238. Author: aristotle, Quote: Maybe crying is a means of cleaning yourself out emotionally. Or maybe it's your last resort; the only way to express yourself when words fail, the same as when you were a baby and had no words.
# 239. Author: aristotle, Quote: Nature does nothing in vain. Therefore, it is imperative for persons to act in accordance with their nature and develop their latent talents, in order to be content and complete.
# 240. Author: aristotle, Quote: The ideal man takes joy in doing favors for others.
# 276. Author: aristotle, Quote: That which is excellent endures.
# 277. Author: aristotle, Quote: The aim of art is to represent not the outward appearance of things, but their inward significance.
# 278. Author: aristotle, Quote: A man's happiness consists in the free exercise of his highest faculties.
# 279. Author: aristotle, Quote: For, what is the best choice for each individual is the highest it is possible for him to achieve.
# 280. Author: aristotle, Quote: Good has two meanings: it means that which is good absolutely and that which is good for somebody.
# 281. Author: aristotle, Quote: Law is a mind without reason.
# 282. Author: aristotle, Quote: Those who act receive the prizes.
# 283. Author: aristotle, Quote: Suppose, then, that all men were sick or deranged, save one or two of them who were healthy and of right mind. It would then be the latter two who would be thought to be sick and deranged, and the former not.
# 284. Author: aristotle, Quote: That which is impossible and probable is better than that which is possible and improbable.
# 285. Author: aristotle, Quote: A man becomes a friend whenever being loved he loves in return.
# 286. Author: aristotle, Quote: We are what we continually do.
# 287. Author: aristotle, Quote: Character is that which reveals moral purpose, exposing the class of things a man chooses and avoids.
# 288. Author: aristotle, Quote: Education and morals make the good man, the good statesman, the good ruler.
# 289. Author: aristotle, Quote: The young are heated by Nature as drunken men by wine.
# 290. Author: aristotle, Quote: Happiness is a certain activity of soul in conformity with perfect goodness.
# 291. Author: aristotle, Quote: Revolutions are effected in two ways, by force and by fraud.
# 292. Author: aristotle, Quote: What soon grows old? Gratitude.
# 293. Author: aristotle, Quote: Education and morals will be found almost the whole that goes to make a good man.
# 294. Author: aristotle, Quote: Experience has shown that it is difficult, if not impossible, for a populous state to be run by good laws.
# 295. Author: aristotle, Quote: Wonder implies the desire to learn.
# 296. Author: aristotle, Quote: Bad men are full of repentance.
# 297. Author: aristotle, Quote: It was through the feeling of wonder that men now and at first began to philosophize.
# 298. Author: aristotle, Quote: When you ask a dumb question, you get a smart answer.
# 299. Author: aristotle, Quote: It is not once nor twice but times without number that the same ideas make their appearance in the world.
# 300. Author: aristotle, Quote: The angry man wishes the object of his anger to suffer in return; hatred wishes its object not to exist.
# 301. Author: aristotle, Quote: The duty of rhetoric is to deal with such matters as we deliberate upon without arts or systems to guide us, in the hearing of persons who cannot take in at a glance a complicated argument or follow a long chain of reasoning.
# 302. Author: aristotle, Quote: Men are divided between those who are as thrifty as if they would live forever, and those who are as extravagant as if they were going to die the next day.
# 303. Author: aristotle, Quote: The soul becomes prudent by sitting and being quiet.
# 304. Author: aristotle, Quote: Bashfulness is an ornament to youth, but a reproach to old age.
# 305. Author: aristotle, Quote: Nothing is what rocks dream about.
# 306. Author: aristotle, Quote: The least initial deviation from the truth is multiplied later a thousandfold.
# 307. Author: aristotle, Quote: The antidote for fifty enemies is one friend.
# 308. Author: aristotle, Quote: Happiness is the utilization of one's talents along lines of excellence.
# 309. Author: aristotle, Quote: It is Homer who has chiefly taught other poets the art of telling lies skillfully.
# 310. Author: aristotle, Quote: In educating the young, we steer them by the rudders of pleasure and pain.
# 311. Author: aristotle, Quote: Plot is character revealed by action.
# 312. Author: aristotle, Quote: Humor is the only test of gravity, and gravity of humor; for a subject which will not bear raillery is suspicious, and a jest which will not bear serious examination is false wit.
# 382. Author: artemiou, Quote: Virtue is given to all, but only the humble fully unlock it.
# 383. Author: artemiou, Quote: Many people say they know me, but they do not. They only see, what I choose to show them.
# 384. Author: artemiou, Quote: Geometry, is God's art.
# 385. Author: artemiou, Quote: Never neglect your daily duties. They build your inner strength.
# 386. Author: artemiou, Quote: Concentration, is a decreasing function. To increase it, differentiate it into vertices.
# 387. Author: artemiou, Quote: The stronger the connections, the better the structure.
# 388. Author: artemiou, Quote: Never define your work. Let your work, define you.
# 389. Author: artemiou, Quote: Accuracy, exists only in theory.
# 390. Author: artemiou, Quote: Those who build the foundations of human knowledge* suffer daily from their ideas.
# 391. Author: artemiou, Quote: The use of recognition, is about sharing ideas for a better world.
# 392. Author: artemiou, Quote: Eternal freedom, leads to corruption. No freedom, leads to war. True freedom, lies in between.
# 393. Author: artemiou, Quote: People rarely forgive* because selfishness, avoids being exposed to the beauty of kindness.
# 394. Author: artemiou, Quote: For every limit we cross, we must set a new one.
# 395. Author: artemiou, Quote: Rules, are not there to be broken. They exist, to teach discipline and morality. And when the time comes, they are replaced by others.
# 396. Author: artemiou, Quote: The essence of 'absolute' truth varies* as each mind generates a different sequence of interpretations.
# 397. Author: artemiou, Quote: What we now regard as the norm, was once a figment of imagination.
# 398. Author: artemiou, Quote: Numerous, - seemingly - unrelated events, occur in our world. However, the probabilistic ascertainment of their interconnection, becomes exponentially cheaper* due to the multi-parametric form of the 'randomness' equation.
# 399. Author: artemiou, Quote: People - usually - unconsciously, transform their behavior* when they are surrounded by other people.
# 400. Author: artemiou, Quote: Motivation, is unnecessary for someone to start something* but it is vital, for someone who wants to complete something.
# 401. Author: artemiou, Quote: The cosmic laws that govern everything, must not break down. We must co-create with them* and never against them.
# 402. Author: artemiou, Quote: Every problem, can be solved through geometry. For they are parts of a bigger picture* a global puzzle.
# 403. Author: artemiou, Quote: Visualization, is the starting point of creation.
# 404. Author: artemiou, Quote: Every human being, is a sequence of numbers* generating beautiful patterns.
# 405. Author: artemiou, Quote: Secrets, create doubts. Doubts, create distance. Distance, creates emotional collapse. Emotional exhaustion, wears down relationships.
# 406. Author: artemiou, Quote: Man, needs religion. Otherwise, he willfully blinds himself, mentally.
# 407. Author: artemiou, Quote: Religion, connects to the divine* the invisible* the powerful* the fascinating* the unimaginable.
# 408. Author: artemiou, Quote: The path of death, can lead only to itself* or to glory.
# 409. Author: artemiou, Quote: The probabilistic outcome for one's life, is the rarest in this world.
# 410. Author: artemiou, Quote: Friendship, is a relationship of mutual love.
# 411. Author: artemiou, Quote: Music, speaks to one's soul, like ideas speak to the mind.
# 412. Author: artemiou, Quote: If one does not have ideas, it is because he has not tried yet.
# 413. Author: artemiou, Quote: Monotony, is the enemy of satisfaction.
# 414. Author: artemiou, Quote: Whatever rule a society has established* is forgotten, in the moment of war.
# 415. Author: artemiou, Quote: Most people, believe in luck. Few, believe in act.
# 416. Author: artemiou, Quote: Everyone, is a child prodigy* and deserves to be honored for his uniqueness.
# 417. Author: artemiou, Quote: If you do not recognize your fears* you will never recognize your strengths.
# ...
# 2245. Author: schopenhauer, Quote: Something of great importance now past is inferior to something of little importance now present, in that the latter is a reality, and related to the former as something to nothing.
# 2246. Author: schopenhauer, Quote: Talent works for money and fame; the motive which moves genius to productivity is, on the other hand, less easy to determine.
# 2247. Author: schopenhauer, Quote: To expect a man to retain everything that he has ever read is like expecting him to carry about in his body everything that he has ever eaten.
# 2248. Author: schopenhauer, Quote: If there is anything in the world that can really be called a man's property, it is surely that which is the result of his mental activity.
# 2249. Author: schopenhauer, Quote: It is only when a man is alone that he is really free.
# 2250. Author: schopenhauer, Quote: The principle of contradiction establishes merely the agreement of concepts, but does not itself produce concepts.
# 2251. Author: schopenhauer, Quote: Honor means that a man is not exceptional; fame, that he is.
# 2252. Author: schopenhauer, Quote: Whatever folly men commit, be their shortcomings or their vices what they may, let us exercise forbearance; remember that when these faults appear in others it is our follies and vices that we behold.
# 2253. Author: schopenhauer, Quote: Memory works like the collection glass in the Camera obscura: it gathers everything together and therewith produces a far more beautiful picture than was present originally.
# 2254. Author: schopenhauer, Quote: Honour is external conscience, and conscience is inward honour.
# 2255. Author: schopenhauer, Quote: There is a wide difference between the original thinker and the merely learned man.
# 2256. Author: schopenhauer, Quote: It is difficult, if not impossible, to define the limit of our reasonable desires in respect of possessions.
# 2257. Author: schopenhauer, Quote: Every state of welfare, every feeling of satisfaction, is negative in its character; that is to say, it consists in freedom from pain, which is the positive element of existence.
# 2258. Author: schopenhauer, Quote: The greatest intellectual capacities are only found in connection with a vehement and passionate will.
# 2259. Author: schopenhauer, Quote: The happiness which we receive from ourselves is greater than that which we obtain from our surroundings... The world in which a person lives shapes itself chiefly by the way in which he or she looks at it.
# 2260. Author: schopenhauer, Quote: It is a clumsy experiment to make; for it involves the destruction of the very consciousness which puts the question and awaits the answer.
# 2261. Author: schopenhauer, Quote: What a man is: that is to say, personality, in the widest sense of the word; under which are included health, strength, beauty, temperament, moral character, intelligence, and education.
# 2262. Author: schopenhauer, Quote: Knowledge is to certain extent a second existence.

# %% [markdown]
# <span style="color:orange">Step 4:LOWERCASING OF FILTERED QUOTES

# %%
# Application of lowercasing to the filtered quotes
for quote in filteredQuotes:
    quote["quote"] = quote["quote"].lower()

print("Sample of quotes after lowercasing:")
for i, quote in enumerate(filteredQuotes[:5]):  # Display the first 5 quotes
    print(f"Author: {quote['author']}, Quote {i + 1}: {quote['quote']}")
# Out:
# Sample of quotes after lowercasing:
# Author: aristotle, Quote 1: be a free thinker and don't accept everything you hear as truth. be critical and evaluate what you believe in.
# Author: aristotle, Quote 2: excellence is never an accident. it is always the result of high intention, sincere effort, and intelligent execution; it represents the wise choice of many alternatives - choice, not chance, determines your destiny.
# Author: aristotle, Quote 3: to appreciate the beauty of a snowflake, it is necessary to stand out in the cold.
# Author: aristotle, Quote 4: he who cannot be a good follower cannot be a good leader.
# Author: aristotle, Quote 5: the weak are always anxious for justice and equality. the strong pay no heed to either.

# %% [markdown]
# <span style="color:orange">Step 5:CLEANING MULTIPLE SPACES

# %%
# Removal of multiple spaces in the filtered and lowercased quotes
for quote in filteredQuotes:
    quote["quote"] = re.sub(r"\s+", " ", quote["quote"]).strip()  # Remove multiple spaces

# Print a sample for verification
print("Sample of quotes after removing multiple spaces:")
for i, quote in enumerate(filteredQuotes[:5]):  # Display the first 5 quotes
    print(f"Quote {i + 1}: Author: {quote['author']}, Quote: {quote['quote']}")
# Out:
# Sample of quotes after removing multiple spaces:
# Quote 1: Author: aristotle, Quote: be a free thinker and don't accept everything you hear as truth. be critical and evaluate what you believe in.
# Quote 2: Author: aristotle, Quote: excellence is never an accident. it is always the result of high intention, sincere effort, and intelligent execution; it represents the wise choice of many alternatives - choice, not chance, determines your destiny.
# Quote 3: Author: aristotle, Quote: to appreciate the beauty of a snowflake, it is necessary to stand out in the cold.
# Quote 4: Author: aristotle, Quote: he who cannot be a good follower cannot be a good leader.
# Quote 5: Author: aristotle, Quote: the weak are always anxious for justice and equality. the strong pay no heed to either.

# %% [markdown]
# <span style="color:orange">Step 6:ADDING [Author] AT THE BEGINNING

# %%
# Adding [Author] at the beginning of each quote
for quote in filteredQuotes:
    author = quote["author"]
    text = quote["quote"]
    quote["quote"] = f"[{author}] {text}"

# Print a sample for verification
print("Sample of quotes after adding [Author]:")
for i, quote in enumerate(filteredQuotes[:5]):  # Display the first 5 quotes
    print(f"Quote {i + 1}: Author: {quote['author']}, Quote: {quote['quote']}")
# Out:
# Sample of quotes after adding [Author]:
# Quote 1: Author: aristotle, Quote: [aristotle] be a free thinker and don't accept everything you hear as truth. be critical and evaluate what you believe in.
# Quote 2: Author: aristotle, Quote: [aristotle] excellence is never an accident. it is always the result of high intention, sincere effort, and intelligent execution; it represents the wise choice of many alternatives - choice, not chance, determines your destiny.
# Quote 3: Author: aristotle, Quote: [aristotle] to appreciate the beauty of a snowflake, it is necessary to stand out in the cold.
# Quote 4: Author: aristotle, Quote: [aristotle] he who cannot be a good follower cannot be a good leader.
# Quote 5: Author: aristotle, Quote: [aristotle] the weak are always anxious for justice and equality. the strong pay no heed to either.

# %% [markdown]
# <span style="color:orange">STEP 7: CREATION OF TRAINING AND EVALUATION DATASETS

# %%
# Splitting the quotes based on the author
authors = set(quote["author"] for quote in filteredQuotes)  # Create a set of unique authors
train_data, eval_data = [], []  # Initialize lists to store training and evaluation data

# Calculation of the number of quotes to include in the evaluation dataset for each author
total_quotes = len(filteredQuotes)  # Total number of filtered quotes
eval_size = int(total_quotes * 0.2)  # 20% of the total dataset for evaluation
quotes_per_author = eval_size // len(authors)  # Ensure an equal number of quotes for each author in the evaluation set

# Distributing quotes into train and evaluation datasets
for author in authors:
    author_quotes = [quote for quote in filteredQuotes if quote["author"] == author]  # Collect quotes for the current author
    train, eval_ = train_test_split(author_quotes, test_size=quotes_per_author, random_state=42)  # Split quotes into train and eval sets
    train_data.extend(train)  # Add train quotes to the overall train dataset
    eval_data.extend(eval_)  # Add evaluation quotes to the overall eval dataset

# Print the size of the training and evaluation datasets
print(f"Train dataset size: {len(train_data)}")
print(f"Eval dataset size: {len(eval_data)}")
# Out:
# Train dataset size: 1812
# Eval dataset size: 450

# %% [markdown]
# <span style="color:orange">Step 8: SAVING AND LOADING DATA FOR TRAINING AND EVALUATION DATASETS

# %%
def save_to_txt(data, path):
    with open(path, "w", encoding="utf-8") as file:  # Open a file at the specified path for writing with UTF-8 encoding
        for quote in data:
            file.write(f"[{quote['author']}] {quote['quote']}\n")  # Write each quote prefixed with the author's name

train_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\Training\train.txt"  # Define the path for the training dataset
eval_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\Training\eval.txt"  # Define the path for the evaluation dataset

save_to_txt(train_data, train_path)  # Save the training data to the specified train_path
save_to_txt(eval_data, eval_path)  # Save the evaluation data to the specified eval_path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 9
#       6 train_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\Training\train.txt"  # Define the path for the training dataset
#       7 eval_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\Training\eval.txt"  # Define the path for the evaluation dataset
# ----> 9 save_to_txt(train_data, train_path)  # Save the training data to the specified train_path
#      10 save_to_txt(eval_data, eval_path)  # Save the evaluation data to the specified eval_path
#
# Cell In[16], line 2, in save_to_txt(data, path)
#       1 def save_to_txt(data, path):
# ----> 2     with open(path, "w", encoding="utf-8") as file:  # Open a file at the specified path for writing with UTF-8 encoding
#       3         for quote in data:
#       4             file.write(f"[{quote['author']}] {quote['quote']}\n")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Kosta\\Python_Projects\\JupyterProject\\Dataset\\PData\\Training\\train.txt'

# %%
# Save to CSV
def save_to_csv(data, path):
    with open(path, "w", newline="", encoding="utf-8") as file:  # Open the file in write mode with UTF-8 encoding
        writer = csv.writer(file)  # Create a writer object for CSV files
        writer.writerow(["Author", "Quote"])  # Write the header row with column names
        for quote in data:
            writer.writerow([quote["author"], quote["quote"]])  # Write each quote and its author as a row in the CSV file

# %%
# Save to JSON
def save_to_json(data, path):
    with open(path, "w", encoding="utf-8") as file:
        json.dump(data, file, ensure_ascii=False, indent=4)  # Save the data to a JSON file using UTF-8 encoding, ensuring non-ASCII characters are preserved, and formatting the JSON with an indentation of 4 spaces for better readability.

# %%
# Definition of paths for CSV and JSON
train_csv_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\CSV\train.csv"  # Path for the training CSV file
eval_csv_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\CSV\eval.csv"   # Path for the evaluation CSV file
train_json_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\JSON\train.json"  # Path for the training JSON file
eval_json_path = r"C:\Users\Kosta\Python_Projects\JupyterProject\Dataset\PData\JSON\eval.json"   # Path for the evaluation JSON file

# Save the data to CSV and JSON files
save_to_csv(train_data, train_csv_path)  # Save the training data to the specified train_csv_path
save_to_csv(eval_data, eval_csv_path)   # Save the evaluation data to the specified eval_csv_path
save_to_json(train_data, train_json_path) # Save the training data to the specified train_json_path
save_to_json(eval_data, eval_json_path)  # Save the evaluation data to the specified eval_json_path

print(f"Data has been saved to CSV and JSON files.")  # Print a confirmation message
# Out:
# Data has been saved to CSV and JSON files.

# %% [markdown]
# # <span style="color:cyan"> IMPLEMENTATION AND FINE-TUNING FOR PHILOSOPHER QUOTES

# %% [markdown]
# <span style="color:orange">LOADING THE GPT-2 MODEL AND TOKENIZER

# %%
# Load the GPT-2 tokenizer pre-trained on a large corpus
tokenizer = TFGPT2LMHeadModel.from_pretrained("gpt2")

# Load the GPT-2 model pre-trained for language modeling tasks
model = TFGPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# All PyTorch model weights were used when initializing TFGPT2LMHeadModel.
#
# All the weights of TFGPT2LMHeadModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# All PyTorch model weights were used when initializing TFGPT2LMHeadModel.
#
# All the weights of TFGPT2LMHeadModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %% [markdown]
# <span style="color:orange">LOADING THE TRAINING DATASET

# %%
# Load the training dataset using the GPT-2 tokenizer
train_dataset = TextDataset(
    tokenizer=tokenizer,  # Use the GPT-2 tokenizer
    file_path=train_path,  # Specify the file path for the training data
    block_size=64)  # Define the block size for the text blocks

# Load the evaluation dataset using the GPT-2 tokenizer
eval_dataset = TextDataset(
    tokenizer=tokenizer,  # Use the GPT-2 tokenizer
    file_path=eval_path,  # Specify the file path for the evaluation data
    block_size=64)  # Define the block size for the text blocks

# Create a data collator for language modeling
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,  # Use the GPT-2 tokenizer
    mlm=False)  # Disable masked language modeling
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[61], line 2
#       1 # Load the training dataset using the GPT-2 tokenizer
# ----> 2 train_dataset = TextDataset(
#       3     tokenizer=tokenizer,  # Use the GPT-2 tokenizer
#       4     file_path=train_path,  # Specify the file path for the training data
#       5     block_size=64)  # Define the block size for the text blocks
#       7 # Load the evaluation dataset using the GPT-2 tokenizer
#       8 eval_dataset = TextDataset(
#       9     tokenizer=tokenizer,  # Use the GPT-2 tokenizer
#      10     file_path=eval_path,  # Specify the file path for the evaluation data
#      11     block_size=64)  # Define the block size for the text blocks
#
# File ~\miniconda3\Lib\site-packages\transformers\utils\dummy_pt_objects.py:163, in TextDataset.__init__(self, *args, **kwargs)
#     162 def __init__(self, *args, **kwargs):
# --> 163     requires_backends(self, ["torch"])
#
# File ~\miniconda3\Lib\site-packages\transformers\utils\import_utils.py:1715, in requires_backends(obj, backends)
#    1713 # Raise an error for users who might not realize that classes without "TF" are torch-only
#    1714 if "torch" in backends and "tf" not in backends and not is_torch_available() and is_tf_available():
# -> 1715     raise ImportError(PYTORCH_IMPORT_ERROR_WITH_TF.format(name))
#    1717 # Raise the inverse error for PyTorch users trying to load TF classes
#    1718 if "tf" in backends and "torch" not in backends and is_torch_available() and not is_tf_available():
#
# ImportError:
# TextDataset requires the PyTorch library but it was not found in your environment.
# However, we were able to find a TensorFlow installation. TensorFlow classes begin
# with "TF", but are otherwise identically named to our PyTorch classes. This
# means that the TF equivalent of the class you tried to import would be "TFTextDataset".
# If you want to use TensorFlow, please use TF classes instead!
#
# If you really do want to use PyTorch please go to
# https://pytorch.org/get-started/locally/ and follow the instructions that
# match your environment.

# %% [markdown]
# <span style="color:orange">TRAINING SETTINGS

# %%
training_args = TrainingArguments(
    output_dir=r"..\Dataset\PData\Training\philosopher-gpt2",  # Set the output directory for the model checkpoints
    overwrite_output_dir=True,  # Overwrite the output directory if it already exists
    num_train_epochs=10,  # Increase the number of training epochs
    per_device_train_batch_size=4,  # Increase the batch size per device
    save_steps=500,  # Save the model every 500 steps
    save_total_limit=2,  # Keep only the last 2 saved checkpoints
    logging_steps=50,  # Log the training progress every 50 steps
    eval_strategy="steps",  # Evaluate the model every 'steps'
    eval_steps=500,  # Evaluate the model every 500 steps
    prediction_loss_only=True,  # Log only the prediction loss during evaluation
    learning_rate=5e-5,  # Reduce the learning rate
    weight_decay=0.01,  # Add weight decay for regularization
    warmup_steps=500,  # Add warmup steps to the learning rate scheduler
    gradient_accumulation_steps=2,  # Enable gradient accumulation to effectively increase the batch size
    fp16=True,)  # Enable mixed precision training if the GPU supports it

# %% [markdown]
# <span style="color:orange">TRAINING THE MODEL

# %%
# Initialize the Trainer object for training the model
trainer = Trainer(
    model=model,  # The GPT-2 model to be trained
    args=training_args,  # Training arguments defined earlier (e.g., epochs, batch size, etc.)
    train_dataset=train_dataset,  # Dataset used for training
    eval_dataset=eval_dataset,  # Dataset used for evaluation during training
    data_collator=data_collator)  # Data collator for batching and processing the data

# Start the training process
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 5
#       1 # Initialize the Trainer object for training the model
#       2 trainer = Trainer(
#       3     model=model,  # The GPT-2 model to be trained
#       4     args=training_args,  # Training arguments defined earlier (e.g., epochs, batch size, etc.)
# ----> 5     train_dataset=train_dataset,  # Dataset used for training
#       6     eval_dataset=eval_dataset,  # Dataset used for evaluation during training
#       7     data_collator=data_collator)  # Data collator for batching and processing the data
#       9 # Start the training process
#      10 trainer.train()
#
# NameError: name 'train_dataset' is not defined

# %% [markdown]
# <span style="color:orange">SAVING THE FINE-TUNED MODEL AND TOKENIZER

# %%
# Save the fine-tuned model
trainer.save_model(r"..\Dataset\PData\Training\philosopher-gpt2")

# Save the tokenizer
tokenizer.save_pretrained(r"..\Dataset\PData\Training\philosopher-gpt2")

# %% [markdown]
# <span style="color:orange">EVALUATION OF THE MODEL

# %%
# Evaluate the model using the evaluation dataset
eval_results = trainer.evaluate()  # This function runs the evaluation process and returns metrics like loss, accuracy, etc.

# Print the evaluation results
print(f"Evaluation results: {eval_results}")  # Display the evaluation metrics to assess the model's performance

# %% [markdown]
# <span style="color:orange">GENERATION OF THE PHILOSOPHICAL QUOTES

# %%
# Load the fine-tuned model for text generation
generator = pipeline("text-generation", model=r"..\Dataset\PData\Training\philosopher-gpt2", tokenizer=tokenizer)

# Define a function to generate a quote based on a philosopher and a topic
def generate_quote(philosopher, topic):
    prompt = f"[{philosopher}] {topic}"  # Create a prompt combining the philosopher and topic
    result = generator(prompt, max_length=50, num_return_sequences=1)  # Generate text using the model
    full_text = result[0]["generated_text"]  # Extract the generated text
    # Extract only the first sentence (based on the first period)
    first_sentence = full_text.split('.')[0] + '.'  # Split the text and return the first sentence
    return first_sentence  # Return the generated sentence

# Create a user interface using Gradio
iface = gr.Interface(
    fn=generate_quote,  # The function to call when generating a quote
    inputs=["text", "text"],  # Input fields: philosopher and topic
    outputs=["text"],  # Output field: generated quote
    title="Philosopher Quote Generator",  # Title of the interface
    description="Enter a philosopher and a topic to generate a new quote."  # Description of the interface
)

# Launch the interface
iface.launch()
